# %%
import pandas as pd
import numpy as np
from PIL import Image

# %% [markdown]
# # Random Choices

# %%
df = pd.read_csv('Expert_Choice/dcm_piwi.csv', index_col=0)

# %%
# df

# %%
# idefix
df_idefix = pd.read_csv('Idefix/1654683111_char_data.txt', sep='\t')


# set, alt, price, time, comfort
# 1     a    5     12    bad
# 1     b    1     20    average
# Out:
#    Unnamed: 0  set    Alt A    Alt B   resp
# 0       Price    1       $5       $1  Alt A
# 1        Time    1   12 min   20 min  Alt A
# 2     Comfort    1      bad  average  Alt A
# 3       Price    2      $10       $5  Alt B
# 4        Time    2   20 min   12 min  Alt B
# 5     Comfort    2  average      bad  Alt B
# 6       Price    3       $1      $10  Alt B
# 7        Time    3   20 min    3 min  Alt B
# 8     Comfort    3     good      bad  Alt B
# 9       Price    4       $1       $5  Alt B
# 10       Time    4   20 min   12 min  Alt B
# 11    Comfort    4      bad  average  Alt B
# 12      Price    5      $10       $1  Alt B
# 13       Time    5    3 min    3 min  Alt B
# 14    Comfort    5     good      bad  Alt B
# 15      Price    6       $5       $1  Alt B
# 16       Time    6    3 min   12 min  Alt B
# 17    Comfort    6  average      bad  Alt B
# 18      Price    7      $10       $5  Alt A
# 19       Time    7   12 min   20 min  Alt A
# ...

# %%
df_num = pd.read_csv('Idefix/1654683111_num_data.txt', sep='\t')
df_num
# Out:
#    Unnamed: 0  Time1  Time2  Price1  Price2  Comfort1  Comfort2  resp
# 0   set1.alt1      1      0       1       0         0         0     1
# 1   set1.alt2      0      1       0       0         1         0     0
# 2   set2.alt1      0      0       0       0         1         0     0
# 3   set2.alt2      1      0       1       0         0         0     1
# 4   set3.alt1      0      1       0       0         0         1     0
# 5   set3.alt2      0      0       0       1         0         0     1
# 6   set4.alt1      0      1       0       0         0         0     0
# 7   set4.alt2      1      0       1       0         1         0     1
# 8   set5.alt1      0      0       0       1         0         1     0
# 9   set5.alt2      0      1       0       1         0         0     1
# 10  set6.alt1      1      0       0       1         1         0     0
# 11  set6.alt2      0      1       1       0         0         0     1
# ...

# %%
random_array = np.random.randint(low=0, high=255,size=(250,250),dtype=np.uint8)
random_im = Image.fromarray(random_array)
# random_im.show()
random_im
# Out:
# <PIL.Image.Image image mode=L size=250x250 at 0x110109A60>
